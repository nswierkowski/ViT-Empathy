# %%
import os
from pathlib import Path
cwd = Path.cwd()

if cwd.name == "notebooks":
    os.chdir(cwd.parent)

# %%
import os, math, json
from pathlib import Path
import numpy as np
import torch
import pandas as pd

import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.spatial.distance import jensenshannon

# %%
RESULTS_PATH = "data/experiments/group_cls_patching/vitbase_neutrality/group_patching_results.pt"  # <- change me

res = torch.load(RESULTS_PATH, map_location="cpu", weights_only=False)
print(res.keys())
print("has original:", "original" in res, "| has patched:", "patched" in res)

# # quick peek
print("streams in layer_0:", list(res["patched"]["layer_1"].keys()))
first_stream = list(res["patched"]["layer_1"].keys())[0]
first_combo = list(res["patched"]["layer_1"][first_stream].keys())[0]
print("example combo:", first_combo)
print("keys inside combo:", res["patched"]["layer_1"][first_stream][first_combo].keys())
# Out:
# dict_keys(['original', 'corrupted', 'patched', 'emotion_map', 'groups_json_path', 'file_key', 'groups', 'combo_names'])
# has original: True | has patched: True
# streams in layer_0: ['block_output', 'attention_output', 'mlp_activation']
# example combo: skin
# keys inside combo: dict_keys(['patched_groups', 'patched_patch_indices', 'final_probs', 'probe_next_layer_probs'])

# %%
res["patched"]["layer_1"][first_stream][first_combo]['probe_next_layer_probs']
# Out:
# array([[4.39777744e-02, 1.00729090e-08, 9.45859053e-01, 1.01567659e-02,
#         1.96535136e-06, 4.43118703e-06]])

# %%
EPS = 1e-12

def to_np_probs(x):
    """Convert stored probs to numpy [C]. Accepts np [1,C], torch [1,C], list, etc."""
    if x is None:
        return None
    if isinstance(x, torch.Tensor):
        x = x.detach().cpu().numpy()
    x = np.asarray(x)
    if x.ndim == 2 and x.shape[0] == 1:
        x = x[0]
    assert x.ndim == 1, f"expected [C], got {x.shape}"
    # numeric safety
    x = np.clip(x, EPS, 1.0)
    x = x / x.sum()
    return x

def kl_div(p, q):
    """KL(p || q)"""
    p = np.clip(p, EPS, 1.0); p = p / p.sum()
    q = np.clip(q, EPS, 1.0); q = q / q.sum()
    return float(np.sum(p * (np.log(p) - np.log(q))))

def js_div(p, q):
    """Jensen-Shannon divergence (base e)."""
    p = np.clip(p, EPS, 1.0); p = p / p.sum()
    q = np.clip(q, EPS, 1.0); q = q / q.sum()
    m = 0.5 * (p + q)
    return 0.5 * kl_div(p, m) + 0.5 * kl_div(q, m)

def l1_dist(p, q):
    return float(np.sum(np.abs(p - q)))

def entropy(p):
    p = np.clip(p, EPS, 1.0); p = p / p.sum()
    return float(-np.sum(p * np.log(p)))

def top1(p):
    return int(np.argmax(p))

def delta_p_correct(p_base, p_new, correct_idx):
    return float(p_new[correct_idx] - p_base[correct_idx])

def delta_p_pred(p_base, p_new):
    pred = top1(p_base)
    return float(p_new[pred] - p_base[pred])

def flip(base_probs, new_probs):
    return top1(base_probs) != top1(new_probs)

# %%
orig_final = to_np_probs(res["original"]["final_probs"])
corr_final = to_np_probs(res["corrupted"]["final_probs"])

correct_idx = None
md = res["original"].get("metadata", {})
if isinstance(md, dict):
    val = md['emotion']
    if isinstance(val, str) and "emotion_map" in res:
        rev = {v[0]:k for k,v in res["emotion_map"].items()}
        if val in rev:
            correct_idx = int(rev[val])

if correct_idx is None:
    correct_idx = int(np.argmax(orig_final))
    print("WARNING: correct_idx not found in metadata. Using baseline top-1 as 'correct' =", correct_idx)
else:
    print("correct_idx from metadata =", correct_idx)

print("orig top1:", np.argmax(orig_final), "corr top1:", np.argmax(corr_final), "correct_idx:", correct_idx)
# Out:
# correct_idx from metadata = 1
# orig top1: 1 corr top1: 2 correct_idx: 1

# %%
res["emotion_map"]
# Out:
# {0: 'neutrality',
#  1: 'happiness',
#  2: 'sadness',
#  3: 'anger',
#  4: 'disgust',
#  5: 'fear'}

# %%
rows = []

base = orig_final

for layer_key, layer_dict in tqdm(res["patched"].items()):
    layer_idx = int(layer_key.split("_")[1])
    for stream, combos in layer_dict.items():
        for combo_name, payload in combos.items():
            p_final = to_np_probs(payload.get("final_probs"))
            p_probe = to_np_probs(payload.get("probe_next_layer_probs"))

            row = {
                "layer": layer_idx,
                "stream": stream,
                "combo": combo_name,
                "n_patches": len(payload.get("patched_patch_indices", [])),
                "final_top1": top1(p_final),
                "final_flip": flip(base, p_final),
                "delta_p_correct": delta_p_correct(base, p_final, correct_idx),
                "delta_p_pred": delta_p_pred(base, p_final),
                "KL_base_to_patched": kl_div(base, p_final),
                "KL_patched_to_base": kl_div(p_final, base),
                "JS": js_div(base, p_final),
                "L1": l1_dist(base, p_final),
                "H_base": entropy(base),
                "H_patched": entropy(p_final),
                "delta_entropy": entropy(p_final) - entropy(base),
            }

            if p_probe is not None:
                row.update({
                    "probe_top1": top1(p_probe),
                    "probe_flip_vs_base": flip(base, p_probe),
                    "probe_delta_p_correct": delta_p_correct(base, p_probe, correct_idx),
                    "probe_JS": js_div(base, p_probe),
                    "probe_L1": l1_dist(base, p_probe),
                })
            else:
                row.update({
                    "probe_top1": None,
                    "probe_flip_vs_base": None,
                    "probe_delta_p_correct": None,
                    "probe_JS": None,
                    "probe_L1": None,
                })

            rows.append(row)

df = pd.DataFrame(rows)
print(df.shape)
df.head()
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 118.31it/s]
# (540, 20)
#    layer        stream       combo  n_patches  final_top1  final_flip  \
# 0      0  block_output        skin         60           2        True
# 1      0  block_output       brows          4           1       False
# 2      0  block_output        lips         12           0        True
# 3      0  block_output        neck         29           1       False
# 4      0  block_output  skin+brows         60           2        True
#
#    delta_p_correct  delta_p_pred  KL_base_to_patched  KL_patched_to_base  \
# 0    -1.000000e+00 -1.000000e+00        2.763102e+01        2.763098e+01
# 1     9.927315e-10  9.927315e-10        1.278978e-10        1.156998e-10
# 2    -9.999999e-01 -9.999999e-01        1.608802e+01        2.749195e+01
# 3    -5.124899e-07 -5.124899e-07        4.901432e-07        1.913260e-06
# 4    -1.000000e+00 -1.000000e+00        2.763102e+01        2.763098e+01
#
#              JS            L1        H_base     H_patched  delta_entropy  \
# 0  6.931472e-01  2.000000e+00  9.642096e-08  3.966511e-05   3.956868e-05
# 1  3.026179e-11  1.985463e-09  9.642096e-08  7.719532e-08  -1.922564e-08
# 2  6.931463e-01  2.000000e+00  9.642096e-08  1.385066e-01   1.385065e-01
# 3  1.673528e-07  1.024980e-06  9.642096e-08  8.018318e-06   7.921897e-06
# 4  6.931472e-01  2.000000e+00  9.642096e-08  3.966511e-05   3.956868e-05
#
#    probe_top1 probe_flip_vs_base  probe_delta_p_correct  probe_JS  probe_L1
# 0         0.0               True              -0.971069  0.627226  1.942139
# 1         0.0               True              -0.983248  0.650451  1.966497
# 2         0.0               True              -0.983952  0.651902  1.967904
# 3         0.0               True              -0.973698  0.631980  1.947396
# 4         0.0               True              -0.971069  0.627226  1.942139

# %%
def show_top(df, metric, n=15, ascending=True):
    display(df.sort_values(metric, ascending=ascending).head(n)[
        ["layer","stream","combo","n_patches", metric, "final_top1", "final_flip"]
    ])

print("Top combos by MOST NEGATIVE delta_p_correct (bigger harm => more negative):")
show_top(df, "delta_p_correct", n=15, ascending=True)

print("\nTop combos by largest JS divergence:")
show_top(df, "JS", n=15, ascending=False)

print("\nFlip rate by combo (aggregated over layer+stream):")
flip_tbl = (
    df.groupby("combo")["final_flip"].mean()
      .sort_values(ascending=False)
      .reset_index()
      .rename(columns={"final_flip":"flip_rate"})
)
display(flip_tbl.head(40))
# Out:
# Top combos by MOST NEGATIVE delta_p_correct (bigger harm => more negative):
#      layer          stream                 combo  n_patches  delta_p_correct  \
# 0        0    block_output                  skin         60             -1.0
# 34       0  mlp_activation            skin+brows         60             -1.0
# 35       0  mlp_activation             skin+lips         60             -1.0
# 36       0  mlp_activation             skin+neck         79             -1.0
# 39       0  mlp_activation             lips+neck         39             -1.0
# 40       0  mlp_activation       skin+brows+lips         60             -1.0
# 41       0  mlp_activation       skin+brows+neck         79             -1.0
# 42       0  mlp_activation        skin+lips+neck         79             -1.0
# 508     11    block_output       brows+lips+neck         42             -1.0
# 507     11    block_output        skin+lips+neck         79             -1.0
# 509     11    block_output  skin+brows+lips+neck         79             -1.0
# 281      6    block_output       skin+brows+neck         79             -1.0
# 280      6    block_output       skin+brows+lips         60             -1.0
# 43       0  mlp_activation       brows+lips+neck         42             -1.0
# 45       1    block_output                  skin         60             -1.0
#
#      final_top1  final_flip
# 0             2        True
# 34            2        True
# 35            2        True
# 36            2        True
# 39            2        True
# 40            2        True
# 41            2        True
# 42            2        True
# 508           2        True
# 507           2        True
# 509           2        True
# 281           2        True
# 280           2        True
# 43            2        True
# 45            2        True
# Top combos by largest JS divergence:
#      layer        stream            combo  n_patches        JS  final_top1  \
# 4        0  block_output       skin+brows         60  0.693147           2
# 0        0  block_output             skin         60  0.693147           2
# 10       0  block_output  skin+brows+lips         60  0.693147           2
# 5        0  block_output        skin+lips         60  0.693147           2
# 45       1  block_output             skin         60  0.693147           2
# 55       1  block_output  skin+brows+lips         60  0.693147           2
# 49       1  block_output       skin+brows         60  0.693147           2
# 50       1  block_output        skin+lips         60  0.693147           2
# 94       2  block_output       skin+brows         60  0.693147           2
# 95       2  block_output        skin+lips         60  0.693147           2
# 90       2  block_output             skin         60  0.693147           2
# 100      2  block_output  skin+brows+lips         60  0.693147           2
# 135      3  block_output             skin         60  0.693147           2
# 139      3  block_output       skin+brows         60  0.693147           2
# 140      3  block_output        skin+lips         60  0.693147           2
#
#      final_flip
# 4          True
# 0          True
# 10         True
# 5          True
# 45         True
# 55         True
# 49         True
# 50         True
# 94         True
# 95         True
# 90         True
# 100        True
# 135        True
# 139        True
# 140        True
# Flip rate by combo (aggregated over layer+stream):
#                    combo  flip_rate
# 0         skin+lips+neck   0.416667
# 1              skin+lips   0.416667
# 2        skin+brows+neck   0.416667
# 3   skin+brows+lips+neck   0.416667
# 4        skin+brows+lips   0.416667
# 5             skin+brows   0.416667
# 6                   skin   0.416667
# 7              skin+neck   0.416667
# 8        brows+lips+neck   0.388889
# 9              lips+neck   0.388889
# 10            brows+lips   0.305556
# 11                  lips   0.305556
# 12            brows+neck   0.166667
# 13                  neck   0.166667
# 14                 brows   0.111111

# %%
def heatmap_layer_combo(df_sub, metric, title=None):
    pivot = df_sub.pivot_table(index="combo", columns="layer", values=metric, aggfunc="mean")

    plt.figure(figsize=(12, max(4, 0.35 * len(pivot.index))))
    plt.imshow(pivot.values, aspect="auto")
    plt.colorbar(label=metric)
    plt.yticks(range(len(pivot.index)), pivot.index)
    plt.xticks(range(len(pivot.columns)), pivot.columns, rotation=90)
    plt.xlabel("Layer")
    plt.ylabel("Combo")
    plt.title(title or f"Heatmap: {metric}")
    plt.tight_layout()
    plt.show()
    return pivot

# %%
METRICS = ["delta_p_correct"]

for stream in sorted(df["stream"].unique()):
    df_s = df[df["stream"] == stream].copy()

    for m in METRICS:
        heatmap_layer_combo(
            df_s, m,
            title=f"{stream} | {m} (mean over same combo/layer if needed)"
        )

# %%
def best_layer_per_combo(df_sub, metric, mode="min"):
    out = []
    for combo, g in df_sub.groupby("combo"):
        if mode == "min":
            idx = g[metric].idxmin()
        else:
            idx = g[metric].idxmax()
        row = g.loc[idx, ["combo","layer","stream",metric,"n_patches","final_top1","final_flip"]].to_dict()
        out.append(row)
    return pd.DataFrame(out).sort_values(metric, ascending=(mode=="min"))

# For delta_p_correct => min is strongest negative
best_delta = best_layer_per_combo(df, "delta_p_correct", mode="min")
display(best_delta.head(20))
# Out:
#                    combo  layer        stream  delta_p_correct  n_patches  \
# 0                  brows     11  block_output             -1.0          4
# 1             brows+lips     11  block_output             -1.0         15
# 2        brows+lips+neck      0  block_output             -1.0         42
# 3             brows+neck      9  block_output             -1.0         32
# 4                   lips     11  block_output             -1.0         12
# 5              lips+neck      0  block_output             -1.0         39
# 6                   neck     10  block_output             -1.0         29
# 7                   skin      0  block_output             -1.0         60
# 8             skin+brows      0  block_output             -1.0         60
# 9        skin+brows+lips      0  block_output             -1.0         60
# 10  skin+brows+lips+neck      0  block_output             -1.0         79
# 11       skin+brows+neck      0  block_output             -1.0         79
# 12             skin+lips      0  block_output             -1.0         60
# 13        skin+lips+neck      0  block_output             -1.0         79
# 14             skin+neck      0  block_output             -1.0         79
#
#     final_top1  final_flip
# 0            2        True
# 1            2        True
# 2            2        True
# 3            2        True
# 4            2        True
# 5            2        True
# 6            2        True
# 7            2        True
# 8            2        True
# 9            2        True
# 10           2        True
# 11           2        True
# 12           2        True
# 13           2        True
# 14           2        True

# %%
TOPK = 15

top_combos = (
    df.groupby("combo")["delta_p_correct"].min()
      .sort_values()
      .head(TOPK)
      .index
      .tolist()
)
print("Top combos:", top_combos)

metric = "delta_p_correct"  # try "JS", "L1"
for stream in sorted(df["stream"].unique()):
    plt.figure(figsize=(18,4))
    for combo in top_combos:
        g = df[(df["combo"]==combo) & (df["stream"]==stream)].sort_values("layer")
        plt.plot(g["layer"], g[metric], marker="o", label=combo)
    plt.axhline(0.0)
    plt.title(f"{stream} | {metric} vs layer (top combos)")
    plt.xlabel("Layer")
    plt.ylabel(metric)
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# Top combos: ['brows', 'brows+lips', 'brows+lips+neck', 'brows+neck', 'lips', 'lips+neck', 'neck', 'skin', 'skin+brows', 'skin+brows+lips', 'skin+brows+lips+neck', 'skin+brows+neck', 'skin+lips', 'skin+lips+neck', 'skin+neck']

# %%
agg = (
    df.groupby(["stream","combo"])
      .agg(
          worst_delta=("delta_p_correct","min"),   # most negative
          max_JS=("JS","max"),
          max_L1=("L1","max"),
          flip_rate=("final_flip","mean"),
          n_patches=("n_patches","max"),
      )
      .reset_index()
)

display(agg.sort_values("worst_delta").head(20))
display(agg.sort_values("max_JS", ascending=False).head(20))
# Out:
#             stream                 combo  worst_delta    max_JS  max_L1  \
# 15    block_output                 brows         -1.0  0.693147     2.0
# 22    block_output                  skin         -1.0  0.693147     2.0
# 29    block_output             skin+neck         -1.0  0.693147     2.0
# 28    block_output        skin+lips+neck         -1.0  0.693147     2.0
# 27    block_output             skin+lips         -1.0  0.693147     2.0
# 26    block_output       skin+brows+neck         -1.0  0.693147     2.0
# 25    block_output  skin+brows+lips+neck         -1.0  0.693147     2.0
# 24    block_output       skin+brows+lips         -1.0  0.693147     2.0
# 23    block_output            skin+brows         -1.0  0.693147     2.0
# 18    block_output            brows+neck         -1.0  0.693147     2.0
# 21    block_output                  neck         -1.0  0.693147     2.0
# 20    block_output             lips+neck         -1.0  0.693147     2.0
# 19    block_output                  lips         -1.0  0.693147     2.0
# 16    block_output            brows+lips         -1.0  0.693147     2.0
# 17    block_output       brows+lips+neck         -1.0  0.693147     2.0
# 32  mlp_activation       brows+lips+neck         -1.0  0.693147     2.0
# 40  mlp_activation  skin+brows+lips+neck         -1.0  0.693147     2.0
# 41  mlp_activation       skin+brows+neck         -1.0  0.693147     2.0
# 42  mlp_activation             skin+lips         -1.0  0.693147     2.0
# 39  mlp_activation       skin+brows+lips         -1.0  0.693147     2.0
#
#     flip_rate  n_patches
# 15   0.250000          4
# 22   1.000000         60
# 29   1.000000         79
# 28   1.000000         79
# 27   1.000000         60
# 26   1.000000         79
# 25   1.000000         79
# 24   1.000000         60
# 23   1.000000         60
# 18   0.416667         32
# 21   0.416667         29
# 20   1.000000         39
# 19   0.750000         12
# 16   0.750000         15
# 17   1.000000         42
# 32   0.083333         42
# 40   0.083333         79
# 41   0.083333         79
# 42   0.083333         60
# 39   0.083333         60
#             stream                 combo  worst_delta    max_JS  max_L1  \
# 27    block_output             skin+lips         -1.0  0.693147     2.0
# 22    block_output                  skin         -1.0  0.693147     2.0
# 23    block_output            skin+brows         -1.0  0.693147     2.0
# 24    block_output       skin+brows+lips         -1.0  0.693147     2.0
# 26    block_output       skin+brows+neck         -1.0  0.693147     2.0
# 17    block_output       brows+lips+neck         -1.0  0.693147     2.0
# 18    block_output            brows+neck         -1.0  0.693147     2.0
# 15    block_output                 brows         -1.0  0.693147     2.0
# 16    block_output            brows+lips         -1.0  0.693147     2.0
# 19    block_output                  lips         -1.0  0.693147     2.0
# 20    block_output             lips+neck         -1.0  0.693147     2.0
# 25    block_output  skin+brows+lips+neck         -1.0  0.693147     2.0
# 21    block_output                  neck         -1.0  0.693147     2.0
# 29    block_output             skin+neck         -1.0  0.693147     2.0
# 28    block_output        skin+lips+neck         -1.0  0.693147     2.0
# 41  mlp_activation       skin+brows+neck         -1.0  0.693147     2.0
# 43  mlp_activation        skin+lips+neck         -1.0  0.693147     2.0
# 44  mlp_activation             skin+neck         -1.0  0.693147     2.0
# 40  mlp_activation  skin+brows+lips+neck         -1.0  0.693147     2.0
# 42  mlp_activation             skin+lips         -1.0  0.693147     2.0
#
#     flip_rate  n_patches
# 27   1.000000         60
# 22   1.000000         60
# 23   1.000000         60
# 24   1.000000         60
# 26   1.000000         79
# 17   1.000000         42
# 18   0.416667         32
# 15   0.250000          4
# 16   0.750000         15
# 19   0.750000         12
# 20   1.000000         39
# 25   1.000000         79
# 21   0.416667         29
# 29   1.000000         79
# 28   1.000000         79
# 41   0.083333         79
# 43   0.083333         79
# 44   0.083333         79
# 40   0.083333         79
# 42   0.083333         60

# %%
C = len(base)
base_top = int(np.argmax(base))

combo_shift_rows = []
for (stream, combo), g in df.groupby(["stream","combo"]):
    top_counts = g["final_top1"].value_counts()
    most_common_top = int(top_counts.index[0])
    frac = float(top_counts.iloc[0] / top_counts.sum())

    worst_row = g.loc[g["delta_p_correct"].idxmin()]
    combo_shift_rows.append({
        "stream": stream,
        "combo": combo,
        "n_patches": int(worst_row["n_patches"]),
        "baseline_top": base_top,
        "most_common_patched_top": most_common_top,
        "most_common_frac": frac,
        "worst_delta_p_correct": float(worst_row["delta_p_correct"]),
        "flip_rate": float(g["final_flip"].mean()),
    })

combo_shift = pd.DataFrame(combo_shift_rows)
display(combo_shift.sort_values(["worst_delta_p_correct"]).head(30))
# Out:
#               stream                 combo  n_patches  baseline_top  \
# 15      block_output                 brows          4             1
# 22      block_output                  skin         60             1
# 29      block_output             skin+neck         79             1
# 28      block_output        skin+lips+neck         79             1
# 27      block_output             skin+lips         60             1
# 26      block_output       skin+brows+neck         79             1
# 25      block_output  skin+brows+lips+neck         79             1
# 24      block_output       skin+brows+lips         60             1
# 23      block_output            skin+brows         60             1
# 18      block_output            brows+neck         32             1
# 21      block_output                  neck         29             1
# 20      block_output             lips+neck         39             1
# 19      block_output                  lips         12             1
# 16      block_output            brows+lips         15             1
# 17      block_output       brows+lips+neck         42             1
# 32    mlp_activation       brows+lips+neck         42             1
# 40    mlp_activation  skin+brows+lips+neck         79             1
# 41    mlp_activation       skin+brows+neck         79             1
# 42    mlp_activation             skin+lips         60             1
# 39    mlp_activation       skin+brows+lips         60             1
# 37    mlp_activation                  skin         60             1
# 38    mlp_activation            skin+brows         60             1
# 43    mlp_activation        skin+lips+neck         79             1
# 44    mlp_activation             skin+neck         79             1
# 35    mlp_activation             lips+neck         39             1
# 34    mlp_activation                  lips         12             1
# 31    mlp_activation            brows+lips         15             1
# 12  attention_output             skin+lips         60             1
# 7   attention_output                  skin         60             1
# 8   attention_output            skin+brows         60             1
#
#     most_common_patched_top  most_common_frac  worst_delta_p_correct  \
# 15                        1          0.750000              -1.000000
# 22                        2          1.000000              -1.000000
# 29                        2          1.000000              -1.000000
# 28                        2          1.000000              -1.000000
# 27                        2          1.000000              -1.000000
# 26                        2          1.000000              -1.000000
# 25                        2          1.000000              -1.000000
# 24                        2          1.000000              -1.000000
# 23                        2          1.000000              -1.000000
# 18                        1          0.583333              -1.000000
# 21                        1          0.583333              -1.000000
# 20                        2          1.000000              -1.000000
# 19                        2          0.500000              -1.000000
# 16                        2          0.666667              -1.000000
# 17                        2          1.000000              -1.000000
# 32                        1          0.916667              -1.000000
# 40                        1          0.916667              -1.000000
# 41                        1          0.916667              -1.000000
# 42                        1          0.916667              -1.000000
# 39                        1          0.916667              -1.000000
# 37                        1          0.916667              -1.000000
# 38                        1          0.916667              -1.000000
# 43                        1          0.916667              -1.000000
# 44                        1          0.916667              -1.000000
# 35                        1          0.916667              -1.000000
# 34                        1          0.916667              -1.000000
# 31                        1          0.916667              -1.000000
# 12                        1          0.833333              -0.999974
# 7                         1          0.833333              -0.999974
# 8                         1          0.833333              -0.999974
#
#     flip_rate
# 15   0.250000
# 22   1.000000
# 29   1.000000
# 28   1.000000
# 27   1.000000
# 26   1.000000
# 25   1.000000
# 24   1.000000
# 23   1.000000
# 18   0.416667
# 21   0.416667
# 20   1.000000
# 19   0.750000
# 16   0.750000
# 17   1.000000
# 32   0.083333
# 40   0.083333
# 41   0.083333
# 42   0.083333
# 39   0.083333
# 37   0.083333
# 38   0.083333
# 43   0.083333
# 44   0.083333
# 35   0.083333
# 34   0.083333
# 31   0.083333
# 12   0.166667
# 7    0.166667
# 8    0.166667
